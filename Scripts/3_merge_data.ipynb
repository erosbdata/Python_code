# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\erosb\08-2023 Instacart Basket Analysis'

# %%
#3 import combined pickle file
df_ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
#4 check shape
df_ords_prods.shape
# Out:
# (32434489, 10)

# %% [markdown]
# Same as exported

# %%
df_prods_checked = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col=False)

# %%
df_prods_checked.shape
# Out:
# (49672, 5)

# %% [markdown]
# Dataframes have different shapes - therefore, use merge.

# %%
#find key
df_ords_prods.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  hour_order_placed  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_prods_checked.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_ords_prods.dtypes
# Out:
# order_id                     int64
# user_id                      int64
# order_number                 int64
# orders_day_of_week           int64
# hour_order_placed            int64
# days_since_prior_order     float64
# product_id                   int64
# add_to_cart_order            int64
# reordered                    int64
# _merge                    category
# dtype: object

# %%
df_prods_checked.dtypes
# Out:
# product_id         int64
# product_name      object
# aisle_id           int64
# department_id      int64
# prices           float64
# dtype: object

# %% [markdown]
# The common key is product_id

# %%
df_all_merged = df_ords_prods.merge(df_prods_checked, on = 'product_id', indicator=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_all_merged = df_ords_prods.merge(df_prods_checked, on = 'product_id', indicator=True)
#
# File ~\OneDrive\Documents\Anaconda3\Lib\site-packages\pandas\core\frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
# ...

# %%
#test
df_all_merged = df_ords_prods.merge(df_prods_checked, on = 'product_id', indicator=False)

# %% [markdown]
# indicator=False and indicator=_exist both work for the merge
# indicator=True does not - must be some conflict between the two columns

# %%
df_all_merged
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32404854   1320836   202557            17                   2
# 32404855     31526   202557            18                   5
# 32404856    758936   203436             1                   2
# 32404857   2745165   203436             2                   3
# 32404858   3093936   205420             1                   4
#
#           hour_order_placed  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %%
#5 combine prods with ords_prods
df_all_merged = df_ords_prods.merge(df_prods_checked, on = 'product_id', indicator='_exist')

# %%
df_all_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  hour_order_placed  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices _exist
# ...

# %%
df_all_merged.shape
# Out:
# (32404859, 15)

# %%
df_all_merged['_exist'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _exist, dtype: int64

# %% [markdown]
# The shape of the merged dataframe has the expected number of rows and columns. The merge flag shows all merges are full matches.

# %%
#export as pickle
df_all_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
